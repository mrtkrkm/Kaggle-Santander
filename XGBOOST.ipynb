# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedKFold
import lightgbm as lgb
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import roc_auc_score
import warnings
import xgboost as xgb
warnings.filterwarnings('ignore')

# %%
df_train=pd.read_csv('../input/santander-customer-transaction-prediction/train.csv')
df_test=pd.read_csv('../input/santander-customer-transaction-prediction/test.csv')
df_sample=pd.read_csv('../input/santander-customer-transaction-prediction/sample_submission.csv')
synthetic = np.load('../input/list-of-fake-samples-and-public-private-lb-split/synthetic_samples_indexes.npy')
test_real = df_test.iloc[~df_test.index.isin(synthetic)]

# %%
print(df_train.shape)
print(df_test.shape)
# Out:
# (200000, 202)
# (200000, 201)

# %%
prediction =pd.DataFrame()
oof=pd.DataFrame()

prediction['Id']=df_test['ID_code']
prediction['predict']=0

oof['Id']=df_train['ID_code']
oof['predict']=0


df_train.drop(['ID_code'], axis=1, inplace=True)
df_test.drop(['ID_code'], axis=1, inplace=True)
test_real.drop(['ID_code'], axis=1, inplace=True)

# %%
target=df_train['target']
df_train.drop(['target'], axis=1, inplace=True)

# %%
print(df_train.shape)
print(df_test.shape)
# Out:
# (200000, 200)
# (200000, 200)

# %%
def add_fe(col, dfr,dfo):
    vc=dfr[col].value_counts(dropna=False)
    dfo[col+'_fe']=dfo[col].map(vc)/vc.max()
    return dfo

# %%
cs=[col for col in df_train.columns if col not in ['ID_code','target']]
train_index=df_train.shape[0]
alls=pd.concat([df_train,test_real])
allo=pd.concat([df_train,df_test])
cols=alls.columns
for col in cs:
    add_fe(col,alls,allo)
df_train=allo[:train_index]
df_test=allo[train_index:]

print(df_train.shape)
print(df_test.shape)
# Out:
# (200000, 400)
# (200000, 400)

# %%
def mult_with_fe(col,df):
    df[col+'_mult']=df[col]*df[col+'_fe']
    return df

for c in cs:
    df_train=mult_with_fe(c,df_train)
    df_test=mult_with_fe(c,df_test)

print(df_train.shape)
print(df_test.shape)
# Out:
# (200000, 600)
# (200000, 600)

# %%
del test_real,synthetic

# %%
params={
    'objective':"binary:logistic", 
    'eval_metric':'auc',
    'booster':"gbtree",
    'tree_method':'gpu_hist',
    'eta':0.01,
    'min_child_weight':50,
    'subsample':0.9,
    'max_depth':3,
    'colsample_bytree':0.7,
    'silent':True
}

# %%
folds=StratifiedKFold(n_splits=5, shuffle=True, random_state=0)

# %%
import gc
cols=[col for col in df_train.columns if col not in ['ID_code','target']]

# %%
for fold_, (trn_, val_) in enumerate(folds.split(df_train, target)):
    
    print('Fold {}'.format(fold_))
    train_data=xgb.DMatrix(df_train.iloc[trn_][cols], label=target.iloc[trn_])
    val_data=xgb.DMatrix(df_train.iloc[val_][cols], label=target.iloc[val_])
    watchlist=[(train_data, 'train'), (val_data, 'val')]

    num_round=100000
    clfxg=xgb.train(params, train_data, num_round, watchlist, early_stopping_rounds=500, verbose_eval=200)
    oof['predict'][val_]=clfxg.predict(xgb.DMatrix(df_train.iloc[val_][cols]), ntree_limit=clfxg.best_ntree_limit)
        
    prediction['predict'] +=clfxg.predict(xgb.DMatrix(df_test[cols]), ntree_limit=clfxg.best_ntree_limit)/folds.n_splits
    gc.collect()
print(roc_auc_score(target,oof['predict']))
# Out:
# Fold 0
# [0]	train-auc:0.591493	val-auc:0.591579
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 500 rounds.
# [200]	train-auc:0.750525	val-auc:0.735907
# [400]	train-auc:0.812339	val-auc:0.791587
# [600]	train-auc:0.842467	val-auc:0.81824
# [800]	train-auc:0.861318	val-auc:0.835025
# [1000]	train-auc:0.874564	val-auc:0.84745
# [1200]	train-auc:0.884532	val-auc:0.8564
# [1400]	train-auc:0.892292	val-auc:0.863204
# [1600]	train-auc:0.898698	val-auc:0.86869
# [1800]	train-auc:0.904039	val-auc:0.873288
# [2000]	train-auc:0.908661	val-auc:0.877159
# [2200]	train-auc:0.912525	val-auc:0.880486
# [2400]	train-auc:0.915926	val-auc:0.883342
# [2600]	train-auc:0.919013	val-auc:0.885803
# [2800]	train-auc:0.921652	val-auc:0.887923
# [3000]	train-auc:0.923973	val-auc:0.889852
# [3200]	train-auc:0.926028	val-auc:0.891506
# [3400]	train-auc:0.928028	val-auc:0.893223
# [3600]	train-auc:0.929882	val-auc:0.894682
# [3800]	train-auc:0.931535	val-auc:0.895995
# [4000]	train-auc:0.933078	val-auc:0.897169
# [4200]	train-auc:0.934557	val-auc:0.898359
# [4400]	train-auc:0.935923	val-auc:0.899415
# [4600]	train-auc:0.937218	val-auc:0.900333
# [4800]	train-auc:0.938465	val-auc:0.901249
# [5000]	train-auc:0.939594	val-auc:0.901996
# [5200]	train-auc:0.940754	val-auc:0.902831
# [5400]	train-auc:0.941716	val-auc:0.903531
# [5600]	train-auc:0.942638	val-auc:0.904181
# [5800]	train-auc:0.943595	val-auc:0.904788
# [6000]	train-auc:0.944463	val-auc:0.905331
# [6200]	train-auc:0.94531	val-auc:0.90587
# [6400]	train-auc:0.946108	val-auc:0.906408
# [6600]	train-auc:0.946875	val-auc:0.906854
# [6800]	train-auc:0.947601	val-auc:0.907306
# [7000]	train-auc:0.948288	val-auc:0.907683
# [7200]	train-auc:0.94896	val-auc:0.90802
# [7400]	train-auc:0.949611	val-auc:0.908346
# [7600]	train-auc:0.950275	val-auc:0.908694
# [7800]	train-auc:0.950859	val-auc:0.908943
# [8000]	train-auc:0.951441	val-auc:0.909271
# [8200]	train-auc:0.952023	val-auc:0.909575
# [8400]	train-auc:0.952561	val-auc:0.909804
# [8600]	train-auc:0.953073	val-auc:0.910093
# [8800]	train-auc:0.953615	val-auc:0.910289
# [9000]	train-auc:0.954142	val-auc:0.910505
# [9200]	train-auc:0.954641	val-auc:0.910684
# [9400]	train-auc:0.955096	val-auc:0.910912
# [9600]	train-auc:0.955583	val-auc:0.911116
# [9800]	train-auc:0.95607	val-auc:0.911262
# [10000]	train-auc:0.956537	val-auc:0.91142
# [10200]	train-auc:0.956992	val-auc:0.911568
# [10400]	train-auc:0.957408	val-auc:0.91168
# [10600]	train-auc:0.957837	val-auc:0.911788
# [10800]	train-auc:0.958264	val-auc:0.911858
# [11000]	train-auc:0.958677	val-auc:0.911991
# [11200]	train-auc:0.959104	val-auc:0.912088
# [11400]	train-auc:0.959486	val-auc:0.912195
# [11600]	train-auc:0.959896	val-auc:0.912296
# [11800]	train-auc:0.96029	val-auc:0.912414
# [12000]	train-auc:0.960688	val-auc:0.912518
# [12200]	train-auc:0.961075	val-auc:0.912593
# [12400]	train-auc:0.961442	val-auc:0.912669
# [12600]	train-auc:0.961824	val-auc:0.912775
# [12800]	train-auc:0.962195	val-auc:0.912854
# [13000]	train-auc:0.962555	val-auc:0.912888
# [13200]	train-auc:0.962924	val-auc:0.912974
# [13400]	train-auc:0.96328	val-auc:0.91304
# [13600]	train-auc:0.963623	val-auc:0.913113
# [13800]	train-auc:0.963981	val-auc:0.913189
# [14000]	train-auc:0.964347	val-auc:0.913222
# [14200]	train-auc:0.964674	val-auc:0.913262
# [14400]	train-auc:0.965021	val-auc:0.913321
# [14600]	train-auc:0.965344	val-auc:0.91338
# [14800]	train-auc:0.965685	val-auc:0.913435
# [15000]	train-auc:0.966	val-auc:0.91351
# [15200]	train-auc:0.966302	val-auc:0.913571
# [15400]	train-auc:0.966627	val-auc:0.913623
# [15600]	train-auc:0.966952	val-auc:0.913642
# [15800]	train-auc:0.967278	val-auc:0.913687
# [16000]	train-auc:0.967575	val-auc:0.913733
# [16200]	train-auc:0.967876	val-auc:0.913779
# [16400]	train-auc:0.968192	val-auc:0.91383
# [16600]	train-auc:0.968513	val-auc:0.91387
# [16800]	train-auc:0.968817	val-auc:0.913883
# [17000]	train-auc:0.969125	val-auc:0.913932
# [17200]	train-auc:0.969419	val-auc:0.913925
# [17400]	train-auc:0.969708	val-auc:0.913929
# [17600]	train-auc:0.970002	val-auc:0.913972
# [17800]	train-auc:0.970303	val-auc:0.913984
# [18000]	train-auc:0.97057	val-auc:0.914008
# [18200]	train-auc:0.97085	val-auc:0.913999
# [18400]	train-auc:0.971143	val-auc:0.914001
# [18600]	train-auc:0.971441	val-auc:0.914058
# [18800]	train-auc:0.971722	val-auc:0.914058
# [19000]	train-auc:0.971985	val-auc:0.914091
# [19200]	train-auc:0.972273	val-auc:0.914122
# [19400]	train-auc:0.972542	val-auc:0.914148
# [19600]	train-auc:0.972817	val-auc:0.914148
# [19800]	train-auc:0.973073	val-auc:0.914164
# [20000]	train-auc:0.973355	val-auc:0.914177
# [20200]	train-auc:0.973617	val-auc:0.914194
# [20400]	train-auc:0.973885	val-auc:0.914218
# [20600]	train-auc:0.97414	val-auc:0.914234
# [20800]	train-auc:0.974409	val-auc:0.914218
# Stopping. Best iteration:
# [20499]	train-auc:0.974021	val-auc:0.914253
#
# Fold 1
# [0]	train-auc:0.595233	val-auc:0.58691
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 500 rounds.
# [200]	train-auc:0.749083	val-auc:0.726863
# [400]	train-auc:0.809874	val-auc:0.784829
# [600]	train-auc:0.841025	val-auc:0.815639
# [800]	train-auc:0.860907	val-auc:0.834585
# [1000]	train-auc:0.874147	val-auc:0.846787
# [1200]	train-auc:0.883808	val-auc:0.855563
# [1400]	train-auc:0.891302	val-auc:0.862334
# [1600]	train-auc:0.897562	val-auc:0.86798
# [1800]	train-auc:0.903152	val-auc:0.873207
# [2000]	train-auc:0.907584	val-auc:0.877328
# [2200]	train-auc:0.911696	val-auc:0.881007
# [2400]	train-auc:0.915367	val-auc:0.884064
# [2600]	train-auc:0.918538	val-auc:0.886717
# [2800]	train-auc:0.921223	val-auc:0.888889
# [3000]	train-auc:0.923644	val-auc:0.890817
# [3200]	train-auc:0.925877	val-auc:0.892527
# [3400]	train-auc:0.927901	val-auc:0.89416
# [3600]	train-auc:0.929739	val-auc:0.895583
# [3800]	train-auc:0.931445	val-auc:0.896873
# [4000]	train-auc:0.932995	val-auc:0.898072
# [4200]	train-auc:0.93453	val-auc:0.899175
# [4400]	train-auc:0.93594	val-auc:0.900127
# [4600]	train-auc:0.937255	val-auc:0.900909
# [4800]	train-auc:0.938475	val-auc:0.901778
# [5000]	train-auc:0.939568	val-auc:0.902483
# [5200]	train-auc:0.94067	val-auc:0.903154
# [5400]	train-auc:0.941706	val-auc:0.903822
# [5600]	train-auc:0.942681	val-auc:0.904379
# [5800]	train-auc:0.943603	val-auc:0.904899
# [6000]	train-auc:0.944492	val-auc:0.905398
# [6200]	train-auc:0.945322	val-auc:0.905916
# [6400]	train-auc:0.946148	val-auc:0.906433
# [6600]	train-auc:0.946924	val-auc:0.906872
# [6800]	train-auc:0.947645	val-auc:0.907268
# [7000]	train-auc:0.948372	val-auc:0.907667
# [7200]	train-auc:0.949086	val-auc:0.907998
# [7400]	train-auc:0.949782	val-auc:0.908363
# [7600]	train-auc:0.95043	val-auc:0.908674
# [7800]	train-auc:0.951042	val-auc:0.908994
# [8000]	train-auc:0.95166	val-auc:0.909261
# [8200]	train-auc:0.952233	val-auc:0.909519
# [8400]	train-auc:0.952785	val-auc:0.909743
# [8600]	train-auc:0.953355	val-auc:0.909988
# [8800]	train-auc:0.953905	val-auc:0.91016
# [9000]	train-auc:0.954435	val-auc:0.910371
# [9200]	train-auc:0.954902	val-auc:0.910504
# [9400]	train-auc:0.955396	val-auc:0.910652
# [9600]	train-auc:0.955892	val-auc:0.910809
# [9800]	train-auc:0.956354	val-auc:0.910989
# [10000]	train-auc:0.956814	val-auc:0.911115
# [10200]	train-auc:0.957295	val-auc:0.911281
# [10400]	train-auc:0.957751	val-auc:0.911359
# [10600]	train-auc:0.958173	val-auc:0.911462
# [10800]	train-auc:0.95859	val-auc:0.911587
# [11000]	train-auc:0.959006	val-auc:0.911697
# [11200]	train-auc:0.959383	val-auc:0.911776
# [11400]	train-auc:0.959799	val-auc:0.911861
# [11600]	train-auc:0.960191	val-auc:0.911961
# [11800]	train-auc:0.960594	val-auc:0.911992
# [12000]	train-auc:0.96099	val-auc:0.912057
# [12200]	train-auc:0.961381	val-auc:0.912097
# [12400]	train-auc:0.961775	val-auc:0.912134
# [12600]	train-auc:0.962144	val-auc:0.912183
# [12800]	train-auc:0.962519	val-auc:0.912243
# [13000]	train-auc:0.962896	val-auc:0.912314
# [13200]	train-auc:0.96324	val-auc:0.912373
# [13400]	train-auc:0.963609	val-auc:0.912437
# [13600]	train-auc:0.963959	val-auc:0.912483
# [13800]	train-auc:0.964311	val-auc:0.912519
# [14000]	train-auc:0.964655	val-auc:0.912562
# [14200]	train-auc:0.964998	val-auc:0.912558
# [14400]	train-auc:0.965327	val-auc:0.912589
# [14600]	train-auc:0.965653	val-auc:0.912622
# [14800]	train-auc:0.965991	val-auc:0.912672
# [15000]	train-auc:0.966306	val-auc:0.912681
# [15200]	train-auc:0.966629	val-auc:0.912707
# [15400]	train-auc:0.966942	val-auc:0.912759
# [15600]	train-auc:0.967269	val-auc:0.912748
# [15800]	train-auc:0.967587	val-auc:0.912765
# [16000]	train-auc:0.967893	val-auc:0.912782
# [16200]	train-auc:0.96821	val-auc:0.912785
# [16400]	train-auc:0.968522	val-auc:0.912821
# [16600]	train-auc:0.968829	val-auc:0.912832
# [16800]	train-auc:0.969125	val-auc:0.912842
# [17000]	train-auc:0.969431	val-auc:0.912857
# [17200]	train-auc:0.969708	val-auc:0.912873
# [17400]	train-auc:0.970028	val-auc:0.912874
# [17600]	train-auc:0.970327	val-auc:0.912924
# [17800]	train-auc:0.970618	val-auc:0.91297
# [18000]	train-auc:0.970916	val-auc:0.912985
# [18200]	train-auc:0.971191	val-auc:0.913002
# [18400]	train-auc:0.971478	val-auc:0.913027
# [18600]	train-auc:0.971764	val-auc:0.913042
# [18800]	train-auc:0.972043	val-auc:0.913079
# [19000]	train-auc:0.972297	val-auc:0.913077
# [19200]	train-auc:0.97257	val-auc:0.913099
# [19400]	train-auc:0.972858	val-auc:0.913058
# [19600]	train-auc:0.973119	val-auc:0.913061
# Stopping. Best iteration:
# [19209]	train-auc:0.972583	val-auc:0.913105
#
# Fold 2
# [0]	train-auc:0.593992	val-auc:0.590128
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 500 rounds.
# [200]	train-auc:0.743193	val-auc:0.735763
# [400]	train-auc:0.808546	val-auc:0.796958
# [600]	train-auc:0.839316	val-auc:0.824646
# [800]	train-auc:0.859932	val-auc:0.842817
# [1000]	train-auc:0.873284	val-auc:0.854536
# [1200]	train-auc:0.883452	val-auc:0.863027
# [1400]	train-auc:0.891423	val-auc:0.869555
# [1600]	train-auc:0.898055	val-auc:0.874718
# [1800]	train-auc:0.903525	val-auc:0.878989
# [2000]	train-auc:0.908066	val-auc:0.882301
# [2200]	train-auc:0.911947	val-auc:0.885308
# [2400]	train-auc:0.915402	val-auc:0.88786
# [2600]	train-auc:0.91846	val-auc:0.890089
# [2800]	train-auc:0.921239	val-auc:0.892239
# [3000]	train-auc:0.923636	val-auc:0.893861
# [3200]	train-auc:0.925831	val-auc:0.895422
# [3400]	train-auc:0.927765	val-auc:0.896651
# [3600]	train-auc:0.929631	val-auc:0.898061
# [3800]	train-auc:0.931313	val-auc:0.899141
# [4000]	train-auc:0.932901	val-auc:0.90019
# [4200]	train-auc:0.934452	val-auc:0.901182
# [4400]	train-auc:0.935893	val-auc:0.902142
# [4600]	train-auc:0.937224	val-auc:0.902966
# [4800]	train-auc:0.938429	val-auc:0.903667
# [5000]	train-auc:0.939664	val-auc:0.904437
# [5200]	train-auc:0.940756	val-auc:0.905083
# [5400]	train-auc:0.941759	val-auc:0.905625
# [5600]	train-auc:0.942717	val-auc:0.906226
# [5800]	train-auc:0.943656	val-auc:0.906773
# [6000]	train-auc:0.944519	val-auc:0.907296
# [6200]	train-auc:0.9454	val-auc:0.907802
# [6400]	train-auc:0.946239	val-auc:0.908234
# [6600]	train-auc:0.946985	val-auc:0.908587
# [6800]	train-auc:0.947695	val-auc:0.908973
# [7000]	train-auc:0.948397	val-auc:0.909301
# [7200]	train-auc:0.949075	val-auc:0.909668
# [7400]	train-auc:0.949758	val-auc:0.909982
# [7600]	train-auc:0.950377	val-auc:0.910272
# [7800]	train-auc:0.950952	val-auc:0.91053
# [8000]	train-auc:0.951549	val-auc:0.910729
# [8200]	train-auc:0.952123	val-auc:0.910953
# [8400]	train-auc:0.952713	val-auc:0.911174
# [8600]	train-auc:0.953262	val-auc:0.911419
# [8800]	train-auc:0.953773	val-auc:0.911583
# [9000]	train-auc:0.954288	val-auc:0.911755
# [9200]	train-auc:0.954783	val-auc:0.911916
# [9400]	train-auc:0.955277	val-auc:0.912084
# [9600]	train-auc:0.955755	val-auc:0.912248
# [9800]	train-auc:0.956218	val-auc:0.912343
# [10000]	train-auc:0.956656	val-auc:0.912458
# [10200]	train-auc:0.957132	val-auc:0.912605
# [10400]	train-auc:0.957545	val-auc:0.912723
# [10600]	train-auc:0.957972	val-auc:0.91282
# [10800]	train-auc:0.958382	val-auc:0.912935
# [11000]	train-auc:0.958772	val-auc:0.913072
# [11200]	train-auc:0.959189	val-auc:0.913141
# [11400]	train-auc:0.959629	val-auc:0.91321
# [11600]	train-auc:0.960043	val-auc:0.913274
# [11800]	train-auc:0.960416	val-auc:0.913376
# [12000]	train-auc:0.960812	val-auc:0.913427
# [12200]	train-auc:0.961193	val-auc:0.913481
# [12400]	train-auc:0.961557	val-auc:0.913521
# [12600]	train-auc:0.961907	val-auc:0.913569
# [12800]	train-auc:0.962274	val-auc:0.913595
# [13000]	train-auc:0.962633	val-auc:0.913611
# [13200]	train-auc:0.962993	val-auc:0.913694
# [13400]	train-auc:0.963339	val-auc:0.913699
# [13600]	train-auc:0.963697	val-auc:0.913733
# [13800]	train-auc:0.964044	val-auc:0.913757
# [14000]	train-auc:0.964368	val-auc:0.913761
# [14200]	train-auc:0.964688	val-auc:0.913802
# [14400]	train-auc:0.965035	val-auc:0.913823
# [14600]	train-auc:0.965374	val-auc:0.913886
# [14800]	train-auc:0.9657	val-auc:0.913935
# [15000]	train-auc:0.966048	val-auc:0.913996
# [15200]	train-auc:0.96636	val-auc:0.914025
# [15400]	train-auc:0.966681	val-auc:0.91407
# [15600]	train-auc:0.966995	val-auc:0.914104
# [15800]	train-auc:0.96732	val-auc:0.914132
# [16000]	train-auc:0.967636	val-auc:0.914169
# [16200]	train-auc:0.96795	val-auc:0.914182
# [16400]	train-auc:0.968257	val-auc:0.914224
# [16600]	train-auc:0.968566	val-auc:0.914228
# [16800]	train-auc:0.968862	val-auc:0.914249
# [17000]	train-auc:0.969159	val-auc:0.914291
# [17200]	train-auc:0.96947	val-auc:0.91431
# [17400]	train-auc:0.969758	val-auc:0.914341
# [17600]	train-auc:0.970043	val-auc:0.914329
# [17800]	train-auc:0.970347	val-auc:0.914332
# [18000]	train-auc:0.970639	val-auc:0.914356
# [18200]	train-auc:0.970914	val-auc:0.91438
# [18400]	train-auc:0.971199	val-auc:0.914372
# [18600]	train-auc:0.971471	val-auc:0.914382
# [18800]	train-auc:0.971737	val-auc:0.91438
# [19000]	train-auc:0.972013	val-auc:0.914383
# [19200]	train-auc:0.972285	val-auc:0.914384
# Stopping. Best iteration:
# [18860]	train-auc:0.971818	val-auc:0.914395
#
# Fold 3
# [0]	train-auc:0.586051	val-auc:0.59328
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 500 rounds.
# [200]	train-auc:0.747384	val-auc:0.743535
# [400]	train-auc:0.809825	val-auc:0.801349
# [600]	train-auc:0.838876	val-auc:0.828328
# [800]	train-auc:0.857914	val-auc:0.846011
# [1000]	train-auc:0.87154	val-auc:0.857827
# [1200]	train-auc:0.881491	val-auc:0.86633
# [1400]	train-auc:0.889533	val-auc:0.873485
# [1600]	train-auc:0.89625	val-auc:0.878983
# [1800]	train-auc:0.901624	val-auc:0.883534
# [2000]	train-auc:0.906503	val-auc:0.887661
# [2200]	train-auc:0.910554	val-auc:0.890731
# [2400]	train-auc:0.914167	val-auc:0.8937
# [2600]	train-auc:0.91728	val-auc:0.895946
# [2800]	train-auc:0.920127	val-auc:0.898003
# [3000]	train-auc:0.922757	val-auc:0.899945
# [3200]	train-auc:0.924964	val-auc:0.901613
# [3400]	train-auc:0.927062	val-auc:0.90307
# [3600]	train-auc:0.928953	val-auc:0.90441
# [3800]	train-auc:0.930751	val-auc:0.905421
# [4000]	train-auc:0.932381	val-auc:0.906453
# [4200]	train-auc:0.933934	val-auc:0.907395
# [4400]	train-auc:0.935333	val-auc:0.908281
# [4600]	train-auc:0.936626	val-auc:0.908996
# [4800]	train-auc:0.937875	val-auc:0.909713
# [5000]	train-auc:0.939048	val-auc:0.910379
# [5200]	train-auc:0.940182	val-auc:0.910922
# [5400]	train-auc:0.941231	val-auc:0.911523
# [5600]	train-auc:0.942238	val-auc:0.912025
# [5800]	train-auc:0.94313	val-auc:0.912447
# [6000]	train-auc:0.944034	val-auc:0.912869
# [6200]	train-auc:0.944896	val-auc:0.913251
# [6400]	train-auc:0.945751	val-auc:0.913668
# [6600]	train-auc:0.946523	val-auc:0.913989
# [6800]	train-auc:0.947278	val-auc:0.914301
# [7000]	train-auc:0.947991	val-auc:0.914611
# [7200]	train-auc:0.94869	val-auc:0.914887
# [7400]	train-auc:0.949359	val-auc:0.915042
# [7600]	train-auc:0.949989	val-auc:0.915273
# [7800]	train-auc:0.95058	val-auc:0.915457
# [8000]	train-auc:0.951177	val-auc:0.91566
# [8200]	train-auc:0.951762	val-auc:0.915839
# [8400]	train-auc:0.952307	val-auc:0.915986
# [8600]	train-auc:0.952855	val-auc:0.916167
# [8800]	train-auc:0.95337	val-auc:0.916309
# [9000]	train-auc:0.953863	val-auc:0.91646
# [9200]	train-auc:0.95437	val-auc:0.916577
# [9400]	train-auc:0.954856	val-auc:0.916672
# [9600]	train-auc:0.955323	val-auc:0.916764
# [9800]	train-auc:0.95577	val-auc:0.91687
# [10000]	train-auc:0.956212	val-auc:0.916941
# [10200]	train-auc:0.956644	val-auc:0.917061
# [10400]	train-auc:0.957065	val-auc:0.917141
# [10600]	train-auc:0.957505	val-auc:0.917208
# [10800]	train-auc:0.957925	val-auc:0.917292
# [11000]	train-auc:0.958357	val-auc:0.917346
# [11200]	train-auc:0.958759	val-auc:0.917425
# [11400]	train-auc:0.959159	val-auc:0.917477
# [11600]	train-auc:0.959554	val-auc:0.917518
# [11800]	train-auc:0.959919	val-auc:0.917562
# [12000]	train-auc:0.960318	val-auc:0.917601
# [12200]	train-auc:0.960694	val-auc:0.917605
# [12400]	train-auc:0.961085	val-auc:0.917658
# [12600]	train-auc:0.961438	val-auc:0.917739
# [12800]	train-auc:0.961791	val-auc:0.917781
# [13000]	train-auc:0.962172	val-auc:0.917851
# [13200]	train-auc:0.962514	val-auc:0.917884
# [13400]	train-auc:0.962866	val-auc:0.917906
# [13600]	train-auc:0.963223	val-auc:0.917945
# [13800]	train-auc:0.963567	val-auc:0.917967
# [14000]	train-auc:0.963904	val-auc:0.918017
# [14200]	train-auc:0.964244	val-auc:0.918044
# [14400]	train-auc:0.964582	val-auc:0.918052
# [14600]	train-auc:0.964929	val-auc:0.918103
# [14800]	train-auc:0.96525	val-auc:0.918128
# [15000]	train-auc:0.965569	val-auc:0.91814
# [15200]	train-auc:0.965886	val-auc:0.918181
# [15400]	train-auc:0.966202	val-auc:0.918224
# [15600]	train-auc:0.966513	val-auc:0.91826
# [15800]	train-auc:0.966825	val-auc:0.918294
# [16000]	train-auc:0.967134	val-auc:0.918308
# [16200]	train-auc:0.967439	val-auc:0.918338
# [16400]	train-auc:0.967733	val-auc:0.918359
# [16600]	train-auc:0.968038	val-auc:0.918386
# [16800]	train-auc:0.968331	val-auc:0.918433
# [17000]	train-auc:0.968613	val-auc:0.918443
# [17200]	train-auc:0.968878	val-auc:0.918442
# [17400]	train-auc:0.969182	val-auc:0.918465
# [17600]	train-auc:0.969476	val-auc:0.918457
# [17800]	train-auc:0.96976	val-auc:0.918458
# Stopping. Best iteration:
# [17418]	train-auc:0.969201	val-auc:0.918476
#
# Fold 4
# [0]	train-auc:0.591909	val-auc:0.584399
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 500 rounds.
# [200]	train-auc:0.74553	val-auc:0.729502
# [400]	train-auc:0.810096	val-auc:0.793328
# [600]	train-auc:0.840105	val-auc:0.822224
# [800]	train-auc:0.859414	val-auc:0.8405
# [1000]	train-auc:0.872601	val-auc:0.852936
# [1200]	train-auc:0.882695	val-auc:0.861805
# [1400]	train-auc:0.890858	val-auc:0.868785
# [1600]	train-auc:0.897238	val-auc:0.874078
# [1800]	train-auc:0.902556	val-auc:0.878361
# [2000]	train-auc:0.907361	val-auc:0.882236
# [2200]	train-auc:0.911288	val-auc:0.885675
# [2400]	train-auc:0.914908	val-auc:0.888514
# [2600]	train-auc:0.918065	val-auc:0.89113
# [2800]	train-auc:0.9208	val-auc:0.893211
# [3000]	train-auc:0.923238	val-auc:0.894955
# [3200]	train-auc:0.925656	val-auc:0.896838
# [3400]	train-auc:0.92773	val-auc:0.898316
# [3600]	train-auc:0.92951	val-auc:0.899572
# [3800]	train-auc:0.931249	val-auc:0.900793
# [4000]	train-auc:0.932849	val-auc:0.901774
# [4200]	train-auc:0.934452	val-auc:0.902825
# [4400]	train-auc:0.935863	val-auc:0.903663
# [4600]	train-auc:0.937232	val-auc:0.904501
# [4800]	train-auc:0.938434	val-auc:0.905188
# [5000]	train-auc:0.939608	val-auc:0.905861
# [5200]	train-auc:0.940757	val-auc:0.906517
# [5400]	train-auc:0.941811	val-auc:0.907061
# [5600]	train-auc:0.94273	val-auc:0.907588
# [5800]	train-auc:0.943665	val-auc:0.908122
# [6000]	train-auc:0.944558	val-auc:0.908568
# [6200]	train-auc:0.945417	val-auc:0.908961
# [6400]	train-auc:0.946215	val-auc:0.90937
# [6600]	train-auc:0.946974	val-auc:0.90972
# [6800]	train-auc:0.947701	val-auc:0.91014
# [7000]	train-auc:0.948392	val-auc:0.9105
# [7200]	train-auc:0.949054	val-auc:0.910802
# [7400]	train-auc:0.949708	val-auc:0.911126
# [7600]	train-auc:0.950352	val-auc:0.911352
# [7800]	train-auc:0.950947	val-auc:0.911606
# [8000]	train-auc:0.951516	val-auc:0.911821
# [8200]	train-auc:0.952069	val-auc:0.91209
# [8400]	train-auc:0.952615	val-auc:0.912322
# [8600]	train-auc:0.953142	val-auc:0.912502
# [8800]	train-auc:0.953636	val-auc:0.912647
# [9000]	train-auc:0.954137	val-auc:0.912863
# [9200]	train-auc:0.954626	val-auc:0.912987
# [9400]	train-auc:0.955079	val-auc:0.913171
# [9600]	train-auc:0.955559	val-auc:0.913357
# [9800]	train-auc:0.956038	val-auc:0.913493
# [10000]	train-auc:0.956475	val-auc:0.913627
# [10200]	train-auc:0.956945	val-auc:0.913741
# [10400]	train-auc:0.957379	val-auc:0.913892
# [10600]	train-auc:0.957784	val-auc:0.914004
# [10800]	train-auc:0.958221	val-auc:0.914109
# [11000]	train-auc:0.958639	val-auc:0.91425
# [11200]	train-auc:0.959026	val-auc:0.914323
# [11400]	train-auc:0.959423	val-auc:0.914387
# [11600]	train-auc:0.959804	val-auc:0.914509
# [11800]	train-auc:0.960195	val-auc:0.914572
# [12000]	train-auc:0.960588	val-auc:0.914636
# [12200]	train-auc:0.96098	val-auc:0.914716
# [12400]	train-auc:0.961379	val-auc:0.914807
# [12600]	train-auc:0.961775	val-auc:0.914906
# [12800]	train-auc:0.96217	val-auc:0.914982
# [13000]	train-auc:0.96255	val-auc:0.91504
# [13200]	train-auc:0.962902	val-auc:0.915081
# [13400]	train-auc:0.963251	val-auc:0.915115
# [13600]	train-auc:0.963608	val-auc:0.915184
# [13800]	train-auc:0.963954	val-auc:0.915216
# [14000]	train-auc:0.964288	val-auc:0.91524
# [14200]	train-auc:0.96463	val-auc:0.915308
# [14400]	train-auc:0.964964	val-auc:0.915355
# [14600]	train-auc:0.965302	val-auc:0.915368
# [14800]	train-auc:0.96563	val-auc:0.915402
# [15000]	train-auc:0.965942	val-auc:0.915444
# [15200]	train-auc:0.96626	val-auc:0.915471
# [15400]	train-auc:0.966582	val-auc:0.915492
# [15600]	train-auc:0.966915	val-auc:0.915554
# [15800]	train-auc:0.96724	val-auc:0.915587
# [16000]	train-auc:0.967544	val-auc:0.915596
# [16200]	train-auc:0.967857	val-auc:0.915622
# [16400]	train-auc:0.968165	val-auc:0.915646
# [16600]	train-auc:0.968474	val-auc:0.915684
# [16800]	train-auc:0.968767	val-auc:0.915716
# [17000]	train-auc:0.96907	val-auc:0.915747
# [17200]	train-auc:0.969375	val-auc:0.915756
# [17400]	train-auc:0.969681	val-auc:0.915784
# [17600]	train-auc:0.969965	val-auc:0.915808
# [17800]	train-auc:0.970253	val-auc:0.915816
# [18000]	train-auc:0.970538	val-auc:0.915833
# [18200]	train-auc:0.970848	val-auc:0.915854
# [18400]	train-auc:0.971165	val-auc:0.915878
# [18600]	train-auc:0.971449	val-auc:0.915884
# [18800]	train-auc:0.971725	val-auc:0.915879
# [19000]	train-auc:0.971986	val-auc:0.915861
# Stopping. Best iteration:
# [18624]	train-auc:0.97148	val-auc:0.915891
#
# 0.9151990422469913

# %%
df_sample['target']=prediction['predict']
df_sample.to_csv('subtryXGB10.csv',index=False)
oof.to_csv('oof.csv',index=False)
